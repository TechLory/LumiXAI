# %%
from client import Client
client = Client()
# Out:
# Backend Online: LumiXAI Backend Online

# %%
# ATTENTION ! This will delete all existing jobs and their associated result files.
client.clear_history()
# Out:
# Requesting database and file cleanup...
# Database and result files cleared.
# {'status': 'success', 'message': 'Database and result files cleared.'}

# %%
# DEMO
demo_batch = [
    { # JOB 1 (Large)
        "source": "huggingface", 
        "model": "stabilityai/sd-turbo", 
        "attributor": "daam", 
        "prompt": "A car on a track",
        "ignore_special_tokens": False
    },
    { # JOB 2 (Classification)
        "source": "huggingface", 
        "model": "distilbert-base-uncased-finetuned-sst-2-english", 
        "attributor": "captum_ig", 
        "prompt": "This paint is awesome!",
    },
    { # JOB 3 (Classification)
        "source": "huggingface", 
        "model": "distilbert-base-uncased-finetuned-sst-2-english", 
        "attributor": "captum_ig", 
        "prompt": "I hate that film."
    },
    { # JOB 4 (Generation)
        "source": "huggingface", 
        "model": "openai-community/gpt2-large", 
        "attributor": "captum_ig", 
        "prompt": "When I was young, I used to playing"
    },
    { # JOB 5 (Large)
        "source": "huggingface", 
        "model": "stabilityai/sd-turbo", 
        "attributor": "daam", 
        "prompt": "A dog riding a skateboard",
        "ignore_special_tokens": True
    },
    { # JOB 6 (Large sdxl-turbo)
        "source": "huggingface", 
        "model": "stabilityai/sdxl-turbo", 
        "attributor": "daam", 
        "prompt": "A dog riding a skateboard",
        "ignore_special_tokens": False
    }
]


#small_demo_batch = demo_batch[:1]
#results = client.run_smart_batch(small_demo_batch, sort_strategy="fastest_first")



results = client.run_smart_batch(demo_batch, sort_strategy="fastest_first")
# results = client.run_smart_batch(demo_batch, sort_strategy="slowest_first")
# results = client.run_smart_batch(demo_batch, sort_strategy="none")
# Out:
# Starting Smart Batch: 6 jobs in 4 groups.
# Strategy: Shortest Job First (Text -> Images)
# Elaboration:   0%|          | 0/6 [00:00<?, ?it/s]
# Configuration for model: 'distilbert-base-uncased-finetuned-sst-2-english' | Attributor: 'captum_ig'...
#
# Requesting explanation for: 'This paint is awesome!...'
#
# Requesting explanation for: 'I hate that film....'
# Elaboration:  17%|█▋        | 1/6 [00:21<01:47, 21.51s/it]
# Configuration for model: 'openai-community/gpt2-large' | Attributor: 'captum_ig'...
#
# Requesting explanation for: 'When I was young, I used to playing...'
# Elaboration:  50%|█████     | 3/6 [08:50<09:42, 194.24s/it]
# Configuration for model: 'stabilityai/sd-turbo' | Attributor: 'daam'...
#
# Requesting explanation for: 'A car on a track...'
#
# Requesting explanation for: 'A dog riding a skateboard...'
# Elaboration:  83%|████████▎ | 5/6 [11:29<02:02, 122.59s/it]
# Configuration for model: 'stabilityai/sdxl-turbo' | Attributor: 'daam'...
#
# Requesting explanation for: 'A dog riding a skateboard...'
# Elaboration: 100%|██████████| 6/6 [26:07<00:00, 261.18s/it]
#  Global batch completed!

# %%
client.free_memory()
# Out:
# Requesting VRAM cleanup...
# Cleaned up memory and VRAM. Model unloaded.
# {'status': 'success', 'message': 'Cleaned up memory and VRAM. Model unloaded.'}

# %%
print(f"\nStringa finale di test")
# Out:
# Stringa finale di test
